# %% [markdown]
# ### Data Ingestion and Storage

# %%
# using pandas
#Read the dataset from a CSV file

import pandas as pd

# %%
#loading the dataset and reading the CSV files
df = pd.read_csv("C:/Users/PRINCES/Documents/GitHub/Churn-Prediction-Pipeline/data/raw/Telco-Customer-Churn.csv")

# %%
#read out the data
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %% [markdown]
# Storing our data in S3 bucket
# .uploading directly:uploading from the AWS console selecting the S3 bucket.click on upload to select the csv file directly from your local system (automation part)
# .writ a scrit auto upload

# %% [markdown]
# upload our data into s3 bucket using a script

# %%
#use boto3
# !pip install boto3
# Out:
# Requirement already satisfied: boto3 in c:\users\princes\documents\github\churn-prediction-pipeline\venv\lib\site-packages (1.40.35)
# Requirement already satisfied: botocore<1.41.0,>=1.40.35 in c:\users\princes\documents\github\churn-prediction-pipeline\venv\lib\site-packages (from boto3) (1.40.43)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\princes\documents\github\churn-prediction-pipeline\venv\lib\site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.15.0,>=0.14.0 in c:\users\princes\documents\github\churn-prediction-pipeline\venv\lib\site-packages (from boto3) (0.14.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\princes\documents\github\churn-prediction-pipeline\venv\lib\site-packages (from botocore<1.41.0,>=1.40.35->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\users\princes\documents\github\churn-prediction-pipeline\venv\lib\site-packages (from botocore<1.41.0,>=1.40.35->boto3) (2.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\princes\documents\github\churn-prediction-pipeline\venv\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.41.0,>=1.40.35->boto3) (1.17.0)
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install awscli
# Out:
# Requirement already satisfied: awscli in c:\users\princes\documents\github\churn-prediction-pipeline\venv\lib\site-packages (1.42.43)
# Requirement already satisfied: botocore==1.40.43 in c:\users\princes\documents\github\churn-prediction-pipeline\venv\lib\site-packages (from awscli) (1.40.43)
# Requirement already satisfied: docutils<=0.19,>=0.18.1 in c:\users\princes\documents\github\churn-prediction-pipeline\venv\lib\site-packages (from awscli) (0.19)
# Requirement already satisfied: s3transfer<0.15.0,>=0.14.0 in c:\users\princes\documents\github\churn-prediction-pipeline\venv\lib\site-packages (from awscli) (0.14.0)
# Requirement already satisfied: PyYAML<6.1,>=3.10 in c:\users\princes\documents\github\churn-prediction-pipeline\venv\lib\site-packages (from awscli) (6.0.3)
# Requirement already satisfied: colorama<0.4.7,>=0.2.5 in c:\users\princes\documents\github\churn-prediction-pipeline\venv\lib\site-packages (from awscli) (0.4.6)
# Requirement already satisfied: rsa<4.8,>=3.1.2 in c:\users\princes\documents\github\churn-prediction-pipeline\venv\lib\site-packages (from awscli) (4.7.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\princes\documents\github\churn-prediction-pipeline\venv\lib\site-packages (from botocore==1.40.43->awscli) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\princes\documents\github\churn-prediction-pipeline\venv\lib\site-packages (from botocore==1.40.43->awscli) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\users\princes\documents\github\churn-prediction-pipeline\venv\lib\site-packages (from botocore==1.40.43->awscli) (2.5.0)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\princes\documents\github\churn-prediction-pipeline\venv\lib\site-packages (from rsa<4.8,>=3.1.2->awscli) (0.6.1)
# Requirement already satisfied: six>=1.5 in c:\users\princes\documents\github\churn-prediction-pipeline\venv\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore==1.40.43->awscli) (1.17.0)
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#use boto3
import boto3
from botocore.exceptions import ClientError
import os
import sys
from io import StringIO

# %%
#initialize the s3 client
s3_client =boto3.client('s3')

#configuration
bucket_name="pr-churn-bucket"
print("connection sucessfully")
# Out:
# connection sucessfully

# %%
# step 3 upload the csv file to the s3 bucket
def upload_file_to_s3(file_path=None,bucket_name=None,s3_key=None):

    #step1 define the path,bucketname and s3_key
    file_path="C:/Users/PRINCES/Documents/GitHub/Churn/Prediction/Pipeline/Telco/CustomerChurn.csv"
    bucket_name = "pr-churn-bucket"
    s3_key = "raw/Telco-customers-churn.csv"

    #step 2 upload the file

    s3_client.upload_file(file_path,bucket_name,s3_key)

    print(f"Files uploaded to s3://{bucket_name}/{s3_key}sucessfully")

    #step 4 call the function
    
    upload_file_to_s3()

# %% [markdown]
# 2.- data processeing and feature engineering
# -loading the data from s3 bucket
# -understand the data
# -clean the data
# -EDA(exploration data analysis)

# %% [markdown]
# 2a -Loading the data from s3 bucket

# %%
#use a library called boto3
import boto3
from botocore.exceptions import ClientError
import os
import sys
from io import StringIO

# %%
# step 1 -  Defining all our parameters
bucket_name = "pr-churn-bucket"
s3_key = "raw/Telco-customers-churn.csv"

# step 2 - connect to S3
s3 = boto3.client("s3")

#step 3 - extract the data for the folder in s3 bucket
obj = s3.get_object(Bucket=bucket_name, Key=s3_key)

#step4 - load into dataframe (convert it into a pandas dataframe)
df = pd.read_csv(obj["Body"])
print("✅ Data loaded successfully!")
# Out:
# ✅ Data loaded successfully!

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %% [markdown]
# ### 2b - Understand the Data

# %%
# step 1 check the initial rows and columns
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
# step 2- check data info 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %%
# step 3 - describe the satistical summary of the data
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
# step 4 : check for problem in the data

# check for missing values
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
# step 5 - check for duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# 2c Clean the data

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %%
df['TotalCharges']
# Out:
# 0         29.85
# 1        1889.5
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038     1990.5
# 7039     7362.9
# 7040     346.45
# 7041      306.6
# 7042     6844.5
# Name: TotalCharges, Length: 7043, dtype: object

# %%
df['TotalCharges'].isnull().sum()
# Out:
# np.int64(0)

# %%
# step 1 - check Totalcharges which is supoose to be a number not text 
df['TotalCharges'].dtype

# step 2 - convert the data type of TotalCharges to numeric
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# step 2b - check inf or missing values in the column
df['TotalCharges'].isnull().sum()

# step 3  - fill missing values with the mean of the column
df['TotalCharges'] = df['TotalCharges'].fillna(df['TotalCharges'].mean())

# %% [markdown]
# ##3 Eploratory data analysis
# -Exploring the data to derie maenigful insights from the data:
# 1.-understand the solution
# 2.understand the target variable
# 3.numerical features analysis
# 4.categorical features(Non- numeric)
# 5.Bi-variante analysis( comparing the features with the target variable)
# 6. correlation analysis

# %% [markdown]
# ##3a understand the solution
# -churn prediction
# -assuming we have a busness running,we have customers using our services or product
# -for some reason customers are dissatisfied with our service
# -it mean customers are churning or going to churn
# -we avoid by been able to predict the kind of customers that will churn

# %% [markdown]
# 3b understand the target variable
# -the target variable is churn column

# %%
import matplotlib.pyplot as plt
import seaborn as sns

print("Churn Distribution")

df['Churn'].value_counts()
df['Churn'].value_counts(normalize=True) * 100


#visualization
fig , ax = plt.subplots(1,2, figsize=(8,5))
churn_counts = df['Churn'].value_counts()


sns.barplot(x=churn_counts.index, y=churn_counts.values, ax=ax[0])

ax[0].set_title('Churn Counts')
ax[0].set_ylabel('Number of Customers')
ax[0].set_xlabel('Churn')
# Out:
# Churn Distribution
# Text(0.5, 0, 'Churn')

# %% [markdown]
# 3c-numerical  features analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   float64
#  20  Churn             7043 non-null   object
# dtypes: float64(2), int64(2), object(17)
# memory usage: 1.1+ MB

# %%
#numerical columns 

numerical_cols  = ['tenure', 'MonthlyCharges', 'TotalCharges']
df[numerical_cols].describe()
# Out:
#             tenure  MonthlyCharges  TotalCharges
# count  7043.000000     7043.000000   7043.000000
# mean     32.371149       64.761692   2283.300441
# std      24.559481       30.090047   2265.000258
# min       0.000000       18.250000     18.800000
# 25%       9.000000       35.500000    402.225000
# 50%      29.000000       70.350000   1400.550000
# 75%      55.000000       89.850000   3786.600000
# max      72.000000      118.750000   8684.800000

# %%
#step1 bi variate analysis
#comparing the numerical features with the target variable
# step 1 -  Bi-variate analysis (comparing 2 things together)

# picking each of the numerical features and comparing with the target variable ("churn")
target_variable = "churn"
numerical_cols = ['tenure', 'MonthlyCharges', 'TotalCharges']

# we compare them by grouping them side-by-side (using a method called groupby in pandas)

df.groupby('Churn')[numerical_cols].mean().round(2)
# Out:
#        tenure  MonthlyCharges  TotalCharges
# Churn
# No      37.57           61.27       2554.77
# Yes     17.98           74.44       1531.80

# %%
# step 2 - plotting the bi-variate analysis

import matplotlib.pyplot as plt
import seaborn as sns

# step 1 - defined the size of the visualization
fig, ax = plt.subplots(1,3, figsize=(15,5))

# step 2 - we loop through each of the numerical columns and plot them
for i, col in enumerate(numerical_cols):

    # step 3 - we plot each of the numerical columns against the target variable (churn)
    sns.boxplot(x="Churn", y=col, data=df, ax=ax[i])
    ax[i].set_title(f'{col} by Churn')
    ax[i].set_xlabel('Churn')
    ax[i].set_ylabel(col)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 3d - Categorical features Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   float64
#  20  Churn             7043 non-null   object
# dtypes: float64(2), int64(2), object(17)
# memory usage: 1.1+ MB

# %%
# performing univariate analysis (looking at one variable at a time)

# STEP 1- checking the count and percentage of each category in the categorical columns

categorical_cols = ['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService',
                    'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup',]

# step 2 - loop through each of the categorical columns and print the value counts and percentages
for feature in categorical_cols:
    counts = df[feature].value_counts()
    percentages = df[feature].value_counts(normalize=True) * 100

    for category in counts.index:
        print(f"  {category}: {counts[category]} ({percentages[category]:1f}%)")
# Out:
#   Male: 3555 (50.475650%)
#   Female: 3488 (49.524350%)
#   0: 5901 (83.785319%)
#   1: 1142 (16.214681%)
#   No: 3641 (51.696720%)
#   Yes: 3402 (48.303280%)
#   No: 4933 (70.041176%)
#   Yes: 2110 (29.958824%)
#   Yes: 6361 (90.316626%)
#   No: 682 (9.683374%)
#   No: 3390 (48.132898%)
#   Yes: 2971 (42.183729%)
#   No phone service: 682 (9.683374%)
#   Fiber optic: 3096 (43.958540%)
#   DSL: 2421 (34.374556%)
#   No: 1526 (21.666903%)
#   No: 3498 (49.666335%)
#   Yes: 2019 (28.666761%)
#   No internet service: 1526 (21.666903%)
#   No: 3088 (43.844952%)
#   Yes: 2429 (34.488144%)
#   No internet service: 1526 (21.666903%)

# %%
# step 3 - univariate analysit comparing categories and churn rates

target_variable = "Churn"
categorical_cols = ['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService',
                    'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup',]

# step 4 - grouping each of the categorical columns with the target variable (churn)
for feature in categorical_cols:

    # step 5 - calculate the churn rate for each category (categorical column or feature) and group them 
    churn_rates = df.groupby(feature)[target_variable].value_counts(normalize=True).unstack()
    print(f"\nChurn Rates by {feature}:\n{churn_rates}\n")
# Out:
# Churn Rates by gender:
# Churn         No       Yes
# gender
# Female  0.730791  0.269209
# Male    0.738397  0.261603
#
#
# Churn Rates by SeniorCitizen:
# Churn                No       Yes
# SeniorCitizen
# 0              0.763938  0.236062
# 1              0.583187  0.416813
#
#
# Churn Rates by Partner:
# Churn          No       Yes
# Partner
# No       0.670420  0.329580
# Yes      0.803351  0.196649
#
#
# Churn Rates by Dependents:
# Churn             No       Yes
# Dependents
# No          0.687209  0.312791
# Yes         0.845498  0.154502
#
#
# Churn Rates by PhoneService:
# Churn               No       Yes
# PhoneService
# No            0.750733  0.249267
# Yes           0.732904  0.267096
#
#
# Churn Rates by MultipleLines:
# Churn                   No       Yes
# MultipleLines
# No                0.749558  0.250442
# No phone service  0.750733  0.249267
# Yes               0.713901  0.286099
#
#
# Churn Rates by InternetService:
# Churn                  No       Yes
# InternetService
# DSL              0.810409  0.189591
# Fiber optic      0.581072  0.418928
# No               0.925950  0.074050
#
#
# Churn Rates by OnlineSecurity:
# Churn                      No       Yes
# OnlineSecurity
# No                   0.582333  0.417667
# No internet service  0.925950  0.074050
# Yes                  0.853888  0.146112
#
#
# Churn Rates by OnlineBackup:
# Churn                      No       Yes
# OnlineBackup
# No                   0.600712  0.399288
# No internet service  0.925950  0.074050
# Yes                  0.784685  0.215315

# %% [markdown]
# # 4 - Correlation Analysis

# %% [markdown]
# # what is correlation?
# # Correlation is a statistical measure that describes the extent to which two variables are related to each other. It quantifies the strength and direction of the relationship between the variables. Correlation is typically measured using a correlation coefficient, which ranges from -1 to +1.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   float64
#  20  Churn             7043 non-null   object
# dtypes: float64(2), int64(2), object(17)
# memory usage: 1.1+ MB

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges  Churn
# 0           Electronic check          29.85         29.85     No
# 1               Mailed check          56.95       1889.50     No
# 2               Mailed check          53.85        108.15    Yes
# 3  Bank transfer (automatic)          42.30       1840.75     No
# 4           Electronic check          70.70        151.65    Yes
#
# [5 rows x 21 columns]

# %%
#calculate the correlation matrix which works only for numerical columns

# step 1  - we noticed churn column is categorical so we convert it to numeric (correlation only works for numerical columns)
df['Churn_numeric'] = df['Churn'].apply(lambda x: 1 if x == 'Yes' else 0)


# step 2 - define the correction matrix for all the numerical columns including the new churn_numeric column
correlation = df[[
    'tenure', 
    'MonthlyCharges', 
    'TotalCharges', 
    'Churn_numeric'
]].corr()['Churn_numeric'].sort_values(ascending=False)

print(correlation)
# Out:
# Churn_numeric     1.000000
# MonthlyCharges    0.193356
# TotalCharges     -0.199428
# tenure           -0.352229
# Name: Churn_numeric, dtype: float64

# %% [markdown]
# - MonthlyCharges (0.193) Slight positive correlation — customers with higher monthly charges are slightly more likely to churn.
#
# - TotalCharges (-0.199)	Slight negative correlation — customers with higher total charges (i.e., those who’ve paid more over time) are less likely to churn. This makes sense because these are usually long-term customers.
#
# - Tenure (-0.352)	Moderate negative correlation — customers with longer tenure are less likely to churn. In other words, newer customers churn more often.

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... TechSupport  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
# 2                No             DSL            Yes  ...          No
# 3  No phone service             DSL            Yes  ...         Yes
# 4                No     Fiber optic             No  ...          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No              No  Month-to-month              Yes
# 1          No              No        One year               No
# 2          No              No  Month-to-month              Yes
# 3          No              No        One year               No
# 4          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges TotalCharges  Churn  Churn_numeric
# 0           Electronic check          29.85        29.85     No              0
# 1               Mailed check          56.95      1889.50     No              0
# 2               Mailed check          53.85       108.15    Yes              1
# 3  Bank transfer (automatic)          42.30      1840.75     No              0
# 4           Electronic check          70.70       151.65    Yes              1
#
# [5 rows x 22 columns]

# %%
# let visualize the correlation using a heatmap
import matplotlib.pyplot as plt
import seaborn as sns

# step 1 - define the size of the visualization
plt.figure(figsize=(8,6))

# step 2 - create the heatmap
sns.heatmap(df[[
    'tenure', 
    'MonthlyCharges', 
    'TotalCharges', 
    'Churn_numeric'
]].corr(), annot=True, cmap='coolwarm', fmt=".2f")
# Out:
# <Axes: >
